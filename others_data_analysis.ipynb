# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
import pandas as pd
import requests
import os

# %%
DATA_PATH = 'data/'

# %% [markdown]
# # Facilities
# https://www.nyc.gov/site/planning/data-maps/open-data/dwn-selfac.page <br>
# Columns descriptions: https://s-media.nyc.gov/agencies/dcp/assets/files/pdf/data-tools/bytes/facilities_readme.pdf

# %%
facilities_df = gpd.read_file(DATA_PATH + 'Facilities Database - Shapefile.zip')
facilities_df.head()
# Out:
#                 address addressnum           bbl        bin       boro  \
# 0    1700 SEWARD AVENUE       1700  2.035510e+09  2092649.0      BRONX
# 1  801 BARTHOLDI STREET        801  2.046330e+09  2057044.0      BRONX
# 2                  None       None  1.008620e+09  1017016.0  MANHATTAN
# 3   1930 RANDALL AVENUE       1930  2.035280e+09  2090508.0      BRONX
# 4       22201 98 AVENUE      22201  4.108080e+09  4430408.0     QUEENS
#
#    borocode  capacity captype     cd            city  ...  overlevel  \
# 0       2.0       0.0    None  209.0           BRONX  ...       City
# 1       2.0       0.0    None  212.0           BRONX  ...       City
# 2       1.0       0.0    None  105.0        NEW YORK  ...      State
# 3       2.0       0.0    None  209.0           BRONX  ...       City
# 4       4.0       0.0    None  413.0  QUEENS VILLAGE  ...      State
#
#   policeprct schooldist  servarea        streetname  \
# 0       43.0         08     Local     SEWARD AVENUE
# 1       47.0         11     Local  BARTHOLDI STREET
# 2       14.0         02     Local              None
# 3       43.0         08     Local    RANDALL AVENUE
# 4      105.0         29  Regional         98 AVENUE
#
#                                 uid        xcoord         ycoord zipcode  \
# 0  000e429e30120017c73af5e842d6cefb  1.020918e+06  237367.257397   10473
# 1  000f976f2d69b025dda2093070ef0b59  1.022291e+06  257805.905100   10467
# 2  001129c4253330bb6ac71968f8d7f3e2  9.888800e+05  211236.809176   10016
# 3  0017a60d2456ff9f3d9f48b11aaf8001  1.023933e+06  237088.716931   10473
# 4  00193957d1a78172a7e1726a807e90e6  1.059039e+06  200706.299293   11429
#
#                      geometry
# 0  POINT (-73.86752 40.81811)
# 1  POINT (-73.86245 40.87420)
# 2  POINT (-73.98329 40.74646)
# 3  POINT (-73.85663 40.81733)
# 4  POINT (-73.73021 40.71724)
#
# [5 rows x 38 columns]

# %%
facilities_df['factype'].unique()
# Out:
# array(['NYCHA COMMUNITY CENTER - CHILD CARE - UPK 2015',
#        'ELEMENTARY SCHOOL - NON-PUBLIC', 'STATE HISTORIC PLACE',
#        'SUMMER ONLY FEEDING SITE', 'BUS STATION',
#        'REGISTERED ESL SCHOOLS', 'TRIANGLE/PLAZA', 'THEATER',
#        'ELEMENTARY SCHOOL - PUBLIC', 'DANCE', 'COMMERCIAL GARAGE',
#        'DSNY GARAGE', 'COMMERCIAL GARAGE AND PARKING LOT', 'TEXTILES',
#        'ELECTRONICS', 'COMPOST', 'MUSEUM', 'CUSTODIAL', 'FEEDING SITE',
#        'OUTDOOR PARKING - EMPLOYEES', 'NURSING HOME', 'NEW MEDIA',
#        'WASTEWATER PUMPING STATION', 'TOW TRUCK COMPANY', 'LITERATURE',
#        'PUBLIC LIBRARY', 'PLAYGROUND', 'REGISTERED BUSINESS SCHOOLS',
#        'LICENSED PRIVATE SCHOOLS', 'GARDEN', 'HOSPITAL EXTENSION CLINIC',
#        'TRANSFER STATION', 'FIELD OFFICE-PUBLIC', 'VDF',
#        'SCRAP METAL PROCESSING',
#        'JUNIOR HIGH-INTERMEDIATE-MIDDLE SCHOOL - PUBLIC', 'VISUAL ARTS',
#        'INDOOR STORAGE - EQUIPMENT', 'MUSIC', 'K-8 SCHOOL - PUBLIC',
#        'FILM/VIDEO/AUDIO', 'MOBILE HOSPITAL EXTENSION CLINIC',
#        'MULTI-DISCIPLINE, PERFORMING', 'AGENCY OFFICE',
#        'MUNICIPAL PARKING - OUTDOOR',
#        'DIAGNOSTIC AND TREATMENT CENTER EXTENSION CLINIC',
#        'PUBLIC SAFETY FACILITY', 'SCHOOL BASED HOSPITAL EXTENSION CLINIC',
#        'COMMERCIAL PARKING LOT', 'JAIL', 'HIGH SCHOOL - PUBLIC',
#        'WORKFORCE1 CAREER CENTER', 'DOE UNIVERSAL PRE-K',
#        'TRANSIT FACILITY', 'AGENCY EXECUTIVE OFFICE',
#        'TRANSPORTATION FACILITY', 'TRANSIT YARD',
#        'MAINTENANCE, MANAGEMENT, AND OPERATIONS', 'HOSPITAL',
#        'RECYCLABLES HANDLING AND RECOVERY',
#        'MULTI-DISCIPL, PERF & NON-PERF',
#        'DIAGNOSTIC AND TREATMENT CENTER', 'VEHICLE DISMANTLING FACILITY',
#        'GARAGE', 'CHARTER SCHOOL', 'RMW', 'HISTORICAL SOCIETIES',
#        'OUTDOOR PARKING', 'MULTI-DISCIPLINE, NON-PERFORM', 'RAIL LINE',
#        'COURTHOUSE', 'COMBINED MAINTENANCE/STORAGE FACILITY',
#        'JOINTLY OPERATED PLAYGROUND', 'MTA BUS DEPOT',
#        'SANITATION SECTION STATION', 'PROBATION/PRETRIAL SERVICES',
#        'POLICE STATION', 'NYCHA COMMUNITY CENTER - JOB READINESS',
#        'SATELLITE SITE FOR STUDENTS WITH DISABILITIES',
#        'PORT OR MARINE TERMINAL', 'TRANSIT SUBSTATION', 'PUMPING STATION',
#        'OFFICE', 'LEAF', 'HIGH SCHOOL - NON-PUBLIC', 'BRIDGE HOUSE',
#        'NYCT SUBWAY YARD',
#        'SCHOOL BASED DIAGNOSTIC AND TREATMENT CENTER EXTENSION CLINIC',
#        'NEIGHBORHOOD PARK', 'PRE-SCHOOL FOR STUDENTS WITH DISABILITIES',
#        'INDOOR STORAGE (WAREHOUSE)', 'CUNY - 4 YEAR COLLEGE',
#        'MANAGED SITES', 'OTHER SCHOOL - NON-PUBLIC', 'BOROUGH OFFICE',
#        'FACILITIES MAINTENANCE', 'SNAP CENTER', 'HELIPORT', 'HUMANITIES',
#        'ADULT DAY HEALTH CARE PROGRAM - OFFSITE', 'NORC SERVICES',
#        'OUTDOOR STORAGE', 'MALL',
#        'NYCHA COMMUNITY CENTER - COMMUNITY CENTER - CORNERSTONE',
#        '2 YEAR PROPRIETARY', 'JOBS AND SERVICE CENTER',
#        'OFFICE LEASED BY EDUC', 'TRAINING FACILITY',
#        'REGULATED MEDICAL WASTE', 'ZOO',
#        'NYCHA COMMUNITY CENTER - ESL CLASSES', 'MEDICAID OFFICE',
#        'PRIVATE MUSEUMS AND SITES', '4 YEAR PROPRIETARY',
#        'LIRR MAINTENANCE AND OTHER FACILITY', 'ADULT HOME',
#        'FERRY LANDING', 'NYCHA COMMUNITY CENTER - HEAD START', 'CDDHRF',
#        'CEMETERY', 'OUTDOOR STORAGE - BULK MATERIAL', 'FOLK ARTS',
#        'ENRICHED HOUSING PROGRAM', 'WATERFRONT FACILITY',
#        'PUBLIC MUSEUMS AND SITES',
#        'GED-ALTERNATIVE HIGH SCHOOL EQUIVALENCY PREP PROGRAMS', 'STRIP',
#        'UNSPECIFIED DISCIPLINE', 'NYCT MAINTENANCE AND OTHER FACILITY',
#        'POLLUTION CONTROL FACILITY', 'FIELD OFFICE-STAFF',
#        'ADULT DAY CARE', 'NYCHA COMMUNITY CENTER',
#        'OUTDOOR MAINTENANCE/STORAGE FACILITY', 'AMBULANCE STATION',
#        'NYCHA COMMUNITY CENTER - SENIOR CENTER',
#        'MTA PARATRANSIT VEHICLE DEPOT', 'ARCHITECTURE/DESIGN',
#        'WATER POLLUTION CONTROL PLANT', 'COMPOSTING',
#        'CONSTRUCTION AND DEMOLITION PROCESSING',
#        'SECONDARY SCHOOL - PUBLIC', 'LONG TERM HOME HEALTH CARE PROGRAM',
#        '4-YEAR INDEPENDENT', 'PEDESTRIAN PLAZA',
#        'MANNED TRANSPORTATION FACILITY', 'FLAGSHIP PARK',
#        'TRAINING FACILITY - OUTDOOR', 'HOSPICE',
#        'USDA COMMUNITY ELIGIBILITY OPTION', 'OTHER', 'MAINTENANCE',
#        'COMMUNITY PARK', 'MIDDLE SCHOOL - NON-PUBLIC',
#        'SUNY - SPECIALIZED COLLEGES', 'OUTDOOR PARKING - CLIENTS',
#        'FERRY TERMINAL', 'OUTDOOR PARKING - AGENCY VEHICLES',
#        'GRADUATE PROGRAMS ONLY', 'LIRR YARD', 'NATURE AREA',
#        'MUNICIPAL PARKING - INDOOR',
#        'NYCHA COMMUNITY CENTER - COMPUTER LAB',
#        'NYC BUSINESS SOLUTIONS CENTER', 'SPECIAL WASTE',
#        'USED COOKING OIL & YELLOW GREASE PROCESSING', 'ASPHALT PLANT',
#        'NYCHA COMMUNITY CENTER - COMMUNITY CENTER', 'AIRPORT',
#        'BOTANICAL', 'NYCHA POLICE SERVICE', 'UNDEVELOPED',
#        'PUBLIC PARKING',
#        'MOBILE DIAGNOSTIC AND TREATMENT CENTER EXTENSION CLINIC',
#        'NYCHA COMMUNITY CENTER - NYPD', None, 'PUBLIC PARK AND RIDE LOT',
#        'WATERFRONT TRANSPORTATION FACILITY', 'AMTRAK YARD',
#        'NYCHA COMMUNITY CENTER - EDUCATION /LITERACY CENTER',
#        'VEHICLE MAINTENANCE', 'SPECIAL LIBRARIES',
#        'NYCHA COMMUNITY CENTER - ATTAIN LAB', 'RECREATION FIELD/COURTS',
#        'NYCHA COMMUNITY CENTER - TA USE',
#        'NYCHA COMMUNITY CENTER - CHILD CARE', 'USED OIL',
#        'CORRECTIONAL FACILITY', 'LOT', 'DISTRICT COURT',
#        'CITY-STATE PARK',
#        'NYCHA COMMUNITY CENTER - SYEP 2019 (SEE NOTES)', 'SECURITY',
#        'RAIL FACILITY', 'OUTDOOR STORAGE - EQUIPMENT', 'STATE FOREST',
#        '2 YEAR INDEPENDENT', 'PHOTOGRAPHY', 'K-8 SCHOOL - CHARTER',
#        'FIELD OFFICE', 'CERTIFIED HOME HEALTH AGENCY', 'PARKWAY',
#        'NYCHA COMMUNITY CENTER - NYCHA - ORRR', 'SOLID WASTE LANDFILL',
#        'SLUDGE DE-WATERING FACILITY',
#        'SCHOOL BASED CHILD CARE - PRESCHOOL', 'CITY COUNCIL AWARDS',
#        'DAY CARE', 'ANTI-GUN VIOLENCE INITIATIVE',
#        'NY NY III SUPPORTED HOUSING-OMH, SUPPORTED HOUSING-OMH',
#        'CAMP - ALL AGE', 'SYEP MAP TO $UCCESS',
#        'MEDICALLY SUPERVISED OUTPATIENT-OASAS, VOCATIONAL REHABILITATION-OASAS, MEDICALLY MONITORED WITHDRAWAL-OASAS, MEDICALLY SUPERVISED WITHDRAWAL SERVICES OUTPATIENT-OASAS',
#        'TRAIN & EARN', 'SOUP KITCHEN',
#        'ADULT LITERACY - ADULT BASIC EDUCATION/HIGH SCHOOL EQUIVALENCY',
#        'EARLY EDUCATION PROGRAM', "SCHOOL'S OUT NEW YORK CITY (SONYC)",
#        'COMMUNITY BASED PROGRAMS', 'FOOD PANTRY',
#        'MED SUP WITHDRAWAL - INPATIENT', 'ALTERNATIVE TO INCARCERATION',
#        'YOUTH RECREATIONAL SERVICES/YOUTH ATHLETIC LEAGUES',
#        'ADULT LITERACY - ENGLISH FOR SPEAKERS OF OTHER LANGUAGES',
#        'NATURALLY OCCURRING RETIREMENT COMMUNITY (NORC)',
#        'COMPASS ELEMENTARY', 'SUPPORTED HOUSING-OMH',
#        'PARENT SUPPORT PROGRAM', 'INTENSIVE RESIDENTIAL',
#        'HOME CARE/ATTENDANT/MAKER AND HOUSEKEEPING SERVICES',
#        'SYEP AND WORK, LEARN & GROW (WLG)', 'CAREGIVER SERVICES',
#        'OUTPATIENT CLINIC', 'OPIOID OUTPATIENT TREATMENT',
#        'NYCHA COMMUNITY CENTER - NGO STAFF',
#        'SUMMER YOUTH EMPLOYMENT PROGRAM (SYEP) (AGES 14-15)', 'BEACON',
#        'INPATIENT REHABILITATION', 'ASSISTED COMPETITIVE EMPLOYMENT-OMH',
#        'NYCHA COMMUNITY CENTER - HEATING & CCTV',
#        'ADULT OUTREACH SERVICE', 'SUPPORTED SRO-OMH', 'PRE-K CENTER',
#        'SUPPORTED HOUSING-OMH, SUPPORTED SRO-OMH', 'NEON ARTS',
#        'FAMILY SUPPORT SERVICES-OMH',
#        'OUTREACH-OMH, PSYCHOSOCIAL CLUB-OMH, SUPPORTED SRO-OMH, NON-MEDICAID CARE COORDINATION (OMH)-OMH',
#        'LEGAL SERVICES', 'HOUSING SUPPORT', 'JOBS PLUS',
#        'HATE CRIMES PREVENTION', 'ELEMENTARY SCHOOL - CHARTER',
#        'PROGRAMS FOR PEOPLE WITH DISABILITIES',
#        'WORKFORCE 1 CAREER CENTERS', 'CPEP CRISIS OUTREACH-OMH',
#        'TRIAL-LEVEL INDIGENT DEFENSE REPRESENTATION',
#        'SPECIAL DEMO - CITY COUNCIL-OMH', 'SCHOOL-OMH', 'CORNERSTONE',
#        'CLINIC TREATMENT-OMH',
#        'OPPORTUNITY YOUTH: SUPPORTED WORK EXPERIENCE',
#        'CHILD HEALTH CENTER', 'SPECIAL DEMO - CITY COUNCIL-OASAS',
#        'WORKS PLUS', 'COURT ADVOCACY SERVICES', 'COURT BASED PROGRAMS',
#        'LEARN & EARN', 'COMPASS EXPLORE', 'METHADONE MAINTENANCE',
#        '820 STABIL REHAB REINTEGRATION',
#        'JUNIOR HIGH-INTERMEDIATE-MIDDLE SCHOOL - CHARTER',
#        'RECREATION-OPWDD, CASE MANAGEMENT-OPWDD, SUMMER CAMP-OPWDD',
#        'INTERN & EARN', 'METRO-NORTH YARD', 'SECURE DETENTION FACILITY',
#        'TELE/COMP FACILITY', 'SOLID WASTE TRANSFER STATION',
#        'SUMMER YOUTH EMPLOYMENT PROGRAM (SYEP)',
#        'MEDICAL MANAGED DETOXIFICATION', 'ADULT LITERACY',
#        'DISCHARGE AND REENTRY SERVICES', 'RESIDENTIAL REHAB FOR YOUTH',
#        'CIVICS CLASSES', 'NYCHA COMMUNITY CENTER - HEALTH CLINIC',
#        'RECREATION-OPWDD',
#        'SYEP EMERGING LEADERS: LEADERS INFLUENCING TOMORROW',
#        'NYCHA COMMUNITY CENTER - CHILD CARE - UPK 2016',
#        'NYCHA COMMUNITY CENTER - ADULT SOCIAL DAY CARE',
#        'ADOLESCENT IMPACT', 'WASTE TIRE STORAGE', 'SENIORS',
#        'SEAPLANE BASE', 'TRANSITIONAL EMPLOYMENT-OPWDD',
#        'HEALTHY FAMILIES', 'TRANSPORTATION', 'FAMILY JUSTICE CENTER',
#        'HOMEBASE HOMELESSNESS PREVENTION', 'SCIENCE',
#        'CRIME VICTIMS SERVICES', 'AIM',
#        'SUMMER YOUTH EMPLOYMENT PROGRAM (SYEP) (AGES 16-24)',
#        'NYCHA COMMUNITY CENTER - SENIOR CENTER/ COMMUNITY CENTER - CORNERSTONE',
#        'MENTAL HYGIENE DROP-IN CENTERS',
#        'NYCHA COMMUNITY CENTER - COMMUNITY CENTER/SENIOR CENTER',
#        'IMMIGRANT SERVICES', 'SPECIAL DEMO - CITY COUNCIL-OPWDD-OMH',
#        'NYCHA COMMUNITY CENTER - SPORTS - BOXING PROGRAM',
#        'K-12 ALL GRADES SCHOOL - PUBLIC', 'STATE PARK',
#        'HISTORIC HOUSE PARK',
#        'NYCHA COMMUNITY CENTER - CHILD CARE /COMMUNITY CENTER/CREDIT UNION',
#        "NYCHA COMMUNITY CENTER - PLASTERER'S SHOP",
#        'SCRAP METAL PROCESSOR', 'EDUCATIONAL SUPPORT: HIGH SCHOOL YOUTH',
#        'DROP-IN CENTERS',
#        'HOME BASED CRISIS INTERVENTION-OMH, NON-MEDICAID CARE COORDINATION (OMH)-OMH',
#        'HOME BASED CRISIS INTERVENTION-OMH, FAMILY SUPPORT SERVICES-OMH, NON-MEDICAID CARE COORDINATION (OMH)-OMH',
#        'PSYCHOSOCIAL CLUB-OMH, SUPPORTED SRO-OMH', 'ADOLESCENT LITERACY',
#        'SYEP CAREERREADY', 'HOME CARE SERVICES',
#        'NYCHA COMMUNITY CENTER - FAMILY / TEEN PROGRAM',
#        'CASE MANAGEMENT', '820 RESIDENTIAL REINTEGRATION',
#        'CASTLE CLINTON NATIONAL MONUMENT', 'ADULT PROTECTIVE SERVICES',
#        'FATHERHOOD', 'SPECIAL DEMO - CITY COUNCIL-OASAS-OMH',
#        'TIDAL WETLAND', 'NON-MEDICAID CARE COORDINATION (OMH)-OMH',
#        'HAMILTON GRANGE NATIONAL MEMORIAL',
#        'HOME BASED CRISIS INTERVENTION-OMH, CRISIS INTERVENTION-OMH, ADVOCACY SERVICES-OMH, NON-MEDICAID CARE COORDINATION (OMH)-OMH',
#        'SPECIAL DEMO - CITY COUNCIL-OPWDD', 'SUMMER SCHOOLS FOR SWD',
#        'DOE UNIVERSAL PRE-K - CHARTER', '820 REHAB AND REINTEGRATION',
#        'NEXT STEPS', 'MEDIATION SERVICES', 'HIGH SCHOOL - CHARTER',
#        'COMMUNITY RESIDENTIAL', 'ADVOCACY SERVICES-OMH',
#        'APPELLATE INDIGENT CRIMINAL DEFENSE', 'JOB SERVICES',
#        'SPECIAL DEMO - CITY COUNCIL-OPWDD-OASAS-OMH',
#        'OTHER PREVENTION SERVICES-OASAS, PREVENTION RESOURCE CENTER-OASAS, PRIMARY PREVENTION SERVICES-OASAS',
#        'ARCHES', 'DROP-IN CENTER', 'CAMP - SCHOOL AGE',
#        'AMTRAK MAINTENANCE AND OTHER FACILITY', 'WASTE OIL STORAGE',
#        'SPECIAL ED TRAINING RESOURCE CENTERS', 'ADVANCE & EARN',
#        'HOME BASED CRISIS INTERVENTION-OMH, ADVOCACY SERVICES-OMH, NON-MEDICAID CARE COORDINATION (OMH)-OMH',
#        'HOME-DELIVERED MEALS',
#        'CRISIS INTERVENTION-OMH, NON-MEDICAID CARE COORDINATION; (NON-LICENSED PROGRAM)-OMH, OUTREACH-OMH, NON-MEDICAID CARE COORDINATION (OMH)-OMH',
#        'DIAGNOSTIC & TREATMENT CENTER', 'VOCATIONAL SERVICES-OMH',
#        'ACADEMIC LIBRARIES', 'ASSERTIVE COMMUNITY TREATMENT-OMH',
#        'PSYCHOSOCIAL CLUB-OMH',
#        'SUPPORTED HOUSING-OMH, SUPPORTED SRO-OMH, NON-MEDICAID CARE COORDINATION (OMH)-OMH',
#        'FEDERAL DEFENDERS',
#        'NON-MEDICAID CARE COORDINATION; (NON-LICENSED PROGRAM)-OMH',
#        'ALTERNATIVE TO DETENTION',
#        'ADVOCACY SERVICES-OMH, VOCATIONAL SERVICES-OMH, HOME BASED CRISIS INTERVENTION-OMH, NON-MEDICAID CARE COORDINATION; (NON-LICENSED PROGRAM)-OMH, NON-MEDICAID CARE COORDINATION (OMH)-OMH',
#        'INDOOR MAINTENANCE/STORAGE FACILITY', 'APPEALS COURT',
#        'NYCHA COMMUNITY CENTER - SENIOR CENTER/ COMMUNITY CENTER/ CHILD CARE',
#        'INTAKE MEDICAL SERVICES',
#        'SUPPORTED HOUSING-OMH, ASSERTIVE COMMUNITY TREATMENT-OMH',
#        'COMPASS HIGH', 'ADVOCACY SERVICES-OMH, PSYCHOSOCIAL CLUB-OMH',
#        'RECYCLING FACILITY', 'OUTPATIENT REHABILITATION',
#        'MEDICALLY SUPERVISED OUTPATIENT-OASAS, COMMUNITY RESIDENTIAL-OASAS, OUTPATIENT REHABILITATION SERVICES-OASAS',
#        'CUSTOMIZED ASSISTANCE SERVICES (CAS)',
#        'SUPPORTED SRO-OMH, ON-SITE REHABILITATION-OMH, ASSISTED COMPETITIVE EMPLOYMENT-OMH, HOMELESS PLACEMENT SERVICES (NON-LICENSED PROGRAM)-OMH',
#        'NYCHA COMMUNITY CENTER - TA USE - LIGHTING VENDOR',
#        'LEGAL ASSISTANCE', 'CRUISE TERMINAL', 'CRISIS INTERVENTION-OMH',
#        'ICM PLUS', 'FOOD PANTRY/MEAL SERVICES', 'MAOT-A-RESIDENTIAL',
#        'MEDICALLY SUPERVISED OUTPATIENT-OASAS, RESIDENTIAL SERVICES-OASAS',
#        'SHELTER INTAKE', 'OUTREACH-OMH', 'SCHOOL BUS DEPOT',
#        'OUT OF SCHOOL TIME: AFTER-SCHOOL PROGRAMS,SUMMER PROGRAM,SUMMER CAMP',
#        'SUPPORT MENTAL HEALTH',
#        'OUT OF SCHOOL TIME: AFTER-SCHOOL PROGRAMS',
#        'ELEMENTARY SCHOOL - PUBLIC, SPECIAL EDUCATION',
#        'OUTPATIENT MENTAL HEALTH', 'HOUSING: FAMILY SUPPORT,NDA PROGRAMS',
#        'MIDDLE SCHOOL YOUTH: AFTER-SCHOOL PROGRAMS,NDA PROGRAMS,ADOLESCENT LITERACY,YOUTH EDUCATIONAL SUPPORT',
#        'SENIOR SERVICES', 'HOME DELIVERED MEALS',
#        'BUILDINGS/INSTITUTIONS',
#        'YOUNG ADULT INTERNSHIP PROGRAM: JOBS & INTERNSHIPS',
#        'BEACON: AFTER-SCHOOL PROGRAMS',
#        'IN-SCHOOL YOUTH EMPLOYMENT (ISY): AFTER-SCHOOL PROGRAMS,JOBS & INTERNSHIPS,YOUTH EMPLOYMENT',
#        'TRANSITIONAL INDEPENDENT LIVING (TIL): RUNAWAY & HOMELESS YOUTH',
#        'ADULT LITERACY: READING & WRITING,NDA PROGRAMS,ENGLISH LANGUAGE PROGRAM,ESOL,FAMILY LITERACY,ADULT BASIC EDUCATION,ABE/GED',
#        'HIGH-SCHOOL AGED YOUTH: AFTER-SCHOOL PROGRAMS,NDA PROGRAMS,YOUTH EDUCATIONAL SUPPORT',
#        'LEGAL ASSISTANCE PROGRAM: IMMIGRATION SERVICES,IMMIGRANT SUPPORT SERVICES',
#        'SENIORS: NDA PROGRAMS,SENIOR PROGRAMS,OLDER ADULT PROGRAM',
#        'SENIOR CENTER',
#        'ADULT LITERACY: READING & WRITING,NDA PROGRAMS,ENGLISH LANGUAGE PROGRAM,ESOL,FAMILY LITERACY',
#        'FAMILY LITERACY: READING & WRITING,NDA PROGRAMS,FAMILY LITERACY',
#        'FIREHOUSE', 'EMERGENCY/CRISIS MENTAL HEALTH',
#        'BEACON SATELLITE: AFTER-SCHOOL PROGRAMS,BEACON,NYCHA COMMUNITY CENTER',
#        'HEALTHY FAMILIES: FAMILY SUPPORT,NDA PROGRAMS',
#        'FATHERHOOD INITIATIVE: FAMILY SUPPORT,NDA PROGRAMS',
#        'ASSISTED COMPETITIVE EMPLOYMENT-OMH, ASSERTIVE COMMUNITY TREATMENT-OMH',
#        'NON-MEDICAID CARE COORDINATION; (NON-LICENSED PROGRAM)-OMH, ASSERTIVE COMMUNITY TREATMENT-OMH',
#        'VICTIM SERVICES, DOMESTIC VIOLENCE', 'CUNY - GRADUATE CENTER',
#        'SUMMER YOUTH EMPLOYMENT : JOBS & INTERNSHIPS,YOUTH EMPLOYMENT',
#        'HEALTH STAT INITIATIVE: FAMILY SUPPORT,NDA PROGRAMS',
#        'LEGAL SERVICES - IMMIGRANT YOUTH: IMMIGRATION SERVICES,IMMIGRANT SUPPORT SERVICES',
#        'INPATIENT MENTAL HEALTH',
#        'TEEN ACTION PROGRAM: AFTER-SCHOOL PROGRAMS',
#        'NYCHA COMMUNITY CENTER - FAMILY PARTNERSHIPS',
#        'TRANSITIONAL INDEPENDENT LIVING GREEN CHIMNEYS: RUNAWAY & HOMELESS YOUTH',
#        'IMMIGRANT/REFUGEE ASSISTANCE: IMMIGRATION SERVICES,IMMIGRANT SUPPORT SERVICES',
#        'SUPPORTED HOUSING-OMH, ASSERTIVE COMMUNITY TREATMENT-OMH, SUPPORTED SRO-OMH, RESPITE-OMH',
#        'MOBILE ADOLESCENT THERAPY', 'ELDER JUSTICE',
#        'NDA IMMIGRANTS: IMMIGRATION SERVICES,IMMIGRANT SUPPORT SERVICES,NDA PROGRAMS,NDA IMMIGRANTS',
#        'CRISIS SHELTER: RUNAWAY & HOMELESS YOUTH',
#        'SECONDARY SCHOOL - CHARTER', 'WASTEWATER TREATMENT PLANT',
#        'LEGAL SERVICES: IMMIGRATION SERVICES,IMMIGRANT SUPPORT SERVICES',
#        'K-12 ALL GRADES SCHOOL - CHARTER',
#        'NYCHA COMMUNITY CENTER - SENIOR CENTER/COMMUNITY CENTER',
#        'SELF-HELP-OMH, ADVOCACY SERVICES-OMH',
#        'MED SUP WITHDRAWAL-OUTPATIENT',
#        'ON-SITE REHABILITATION-OMH, VOCATIONAL SERVICES-OMH',
#        'RECOVERY CENTER-OMH', 'ACUTE CARE HOSPITAL',
#        'NYCHA COMMUNITY CENTER - CHILD CARE - UPK 2014',
#        'MICA NETWORK-OMH',
#        'NYCHA COMMUNITY CENTER - SENIOR CENTER/ COMMUNITY CENTER',
#        'JOB PLACEMENT INITIATIVE-OASAS', 'EMPLOYMENT FOCUSED SERVICES',
#        'DOMESTIC VIOLENCE PROGRAM: IMMIGRATION SERVICES,IMMIGRANT SUPPORT SERVICES',
#        'OUT-OF-SCHOOL YOUTH EMPLOYMENT (OSY): AFTER-SCHOOL PROGRAMS,JOBS & INTERNSHIPS,YOUTH EMPLOYMENT',
#        'NYCHA COMMUNITY CENTER - JOBS PLUS',
#        'SERVICES - IMMIGRANT FAMILIES: IMMIGRATION SERVICES,IMMIGRANT SUPPORT SERVICES',
#        'SECONDARY SCHOOL - PUBLIC, SPECIAL EDUCATION',
#        'TESTING LABORATORY',
#        'ADULT LITERACY: READING & WRITING,NDA PROGRAMS,ENGLISH LANGUAGE PROGRAM,FAMILY LITERACY,ADULT BASIC EDUCATION,ABE/GED',
#        'K-12 ALL GRADES SCHOOL - PUBLIC, SPECIAL EDUCATION',
#        'K-8 SCHOOL - PUBLIC, SPECIAL EDUCATION',
#        'ON-SITE REHABILITATION-OMH, ASSISTED COMPETITIVE EMPLOYMENT-OMH, ADVOCACY SERVICES-OMH, SUPPORTED SRO-OMH',
#        'MEDICALLY SUPERVISED OUTPATIENT-OASAS, PRIMARY PREVENTION SERVICES-OASAS',
#        'TEEN RAPP',
#        'PSYCHOSOCIAL CLUB-OMH, NON-MEDICAID CARE COORDINATION (OMH)-OMH',
#        'SELF-HELP-OMH, NON-MEDICAID CARE COORDINATION (OMH)-OMH',
#        'CAMP - PRESCHOOL AGE', 'DROP-IN CENTER: RUNAWAY & HOMELESS YOUTH',
#        'CAREERADVANCE',
#        'NYC BUSINESS SOLUTIONS INDUSTRIAL AND TRANSPORTATION',
#        'NYC BUSINESS SOLUTIONS',
#        'AFFIRMATIVE BUSINESS/INDUSTRY-OMH, NON-MEDICAID CARE COORDINATION (OMH)-OMH',
#        'MEDICALLY SUPERVISED OUTPATIENT-OASAS, COMPULSIVE GAMBLING EDUCATION-OASAS',
#        'MEDICALLY SUPERVISED OUTPATIENT-OASAS',
#        'NYCHA COMMUNITY CENTER - CASE MANAGEMENT /CHILD WELFARE PROGRAM',
#        'OTHER PREVENTION SERVICES-OASAS, MEDICALLY SUPERVISED OUTPATIENT-OASAS, PRIMARY PREVENTION SERVICES-OASAS, YOUTH CLUBHOUSE-OASAS',
#        'PEAK CENTERS',
#        'SUPPORTED HOUSING-OMH, NON-MEDICAID CARE COORDINATION (OMH)-OMH',
#        'EMPLOYMENT WORKS', 'BANKRUPTCY COURT', 'RAPID RE-HOUSING',
#        'SELF-HELP-OMH, NON-MEDICAID CARE COORDINATION; (NON-LICENSED PROGRAM)-OMH, ADVOCACY SERVICES-OMH',
#        'JUSTICE PLUS', 'WORK, LEARN & GROW (WLG)', '820 STABIL AND REHAB',
#        'SUNY - HEALTH SCIENCE CENTERS',
#        'OUTREACH-OMH, ADVOCACY SERVICES-OMH, CRISIS/RESPITE BEDS-OMH',
#        'SUMMER YOUTH EMPLOYMENT: JOBS & INTERNSHIPS,YOUTH EMPLOYMENT',
#        'MEDICALLY MONITORED WITHDRAWAL', 'CRISIS/RESPITE BEDS-OMH',
#        'COMMUNITY RESIDENTIAL-OASAS', 'MEDICAL MAINTENANCE',
#        'ON-SITE REHABILITATION-OMH, SUPPORTED SRO-OMH',
#        'HIGH SCHOOL - PUBLIC, SPECIAL EDUCATION',
#        'ADOLESCENT LITERACY: READING & WRITING,NDA PROGRAMS,FAMILY LITERACY',
#        'STORMWATER PUMPING STATION',
#        'NYCHA COMMUNITY CENTER - VOCATIONAL/TRADE SCHOOL',
#        'NYCHA COMMUNITY CENTER - URBAN FAMILY CENTER',
#        'NY NY III SUPPORTED HOUSING-OASAS, SUPPORTED HOUSING-OASAS',
#        'PSYCHOSOCIAL CLUB-OMH, CRISIS/RESPITE BEDS-OMH', 'CAREERCOMPASS',
#        'NYCHA COMMUNITY CENTER - TA USE / NYCHA STORAGE',
#        'ARTICLE 10 PETITION PARENTAL REPRESENTATION',
#        'UNGRADED SCHOOL - CHARTER, SPECIAL EDUCATION',
#        'IMMIGRANT: NDA PROGRAMS,IMMIGRATION SERVICES,IMMIGRANT SUPPORT SERVICES',
#        'TRAINING FACILITY - INDOOR',
#        'NYCHA COMMUNITY CENTER - DOMESTIC VIOLENCE PROGRAM/COUNSELING',
#        'PIER - MARITIME USE', 'YOUTHPATHWAYS',
#        'STONEWALL NATIONAL MONUMENT', 'PANYNJ BUS TERMINAL',
#        'INDOOR STORAGE - SUPPLIES', 'DETENTION CENTER',
#        'NY NY III SUPPORTED HOUSING-OMH',
#        'NY NY III SUPPORTED HOUSING-OASAS',
#        'ADVOCACY SERVICES-OMH, SUPPORTED SRO-OMH',
#        'PRIMARY PREVENTION SERVICES-OASAS',
#        'NYCHA COMMUNITY CENTER - EDUCATION / IHAD LITERACY',
#        'METHADONE MAINTENANCE-OASAS', 'IMMIGRANT FAMILY SERVICES',
#        'NYCHA COMMUNITY CENTER - CHILD CARE /COMMUNITY CENTER',
#        'SYEP CAREER FIRST', 'CUNY - COMMUNITY COLLEGE',
#        'ASSISTED COMPETITIVE EMPLOYMENT-OMH, ADVOCACY SERVICES-OMH, SUPPORTED SRO-OMH',
#        'AFRICAN BURIAL GROUND NATIONAL MONUMENT',
#        'HOME BASED FAMILY TREATMENT-OMH',
#        'HOME BASED CRISIS INTERVENTION-OMH, CRISIS INTERVENTION-OMH',
#        'NYCHA COMMUNITY CENTER - STV CONTRACTOR',
#        'NYCHA COMMUNITY CENTER - COMMUNITY CENTER / SENIOR CENTER',
#        'COMMERCIAL MARKET', 'TESTING FACILITY',
#        'NYCHA COMMUNITY CENTER - COMMUNITY CENTER - DEVELOPMENTAL DISABILITIES',
#        'NYCHA COMMUNITY CENTER - HEALTH CLINIC *', 'SELF-HELP-OMH',
#        'COMPULSIVE GAMBLING SERVICES',
#        'THEODORE ROOSEVELT BIRTHPLACE NATIONAL HISTORIC SITE',
#        'STREET OUTREACH: RUNAWAY & HOMELESS YOUTH',
#        'OUTDOOR STORAGE - AGENCY VEHICLES', 'UNIQUE AREA', 'ANTENNA',
#        'NYCHA COMMUNITY CENTER - SENIOR CENTER/NORC/ CHILD CARE/ COMMUNITY CENTER',
#        'PSYCHOSOCIAL CLUB-OMH, CLINIC TREATMENT-OMH',
#        'GOVERNORS ISLAND NATIONAL MONUMENT', 'NATURAL RESOURCE AREA',
#        'IN USE-RESIDENTIAL STRUCTURE',
#        'NYCHA COMMUNITY CENTER - CHILD CARE *',
#        "COORDINATED CHILDREN'S SERVICES INITIATIVE-OMH",
#        'NYCHA COMMUNITY CENTER - SENIOR SERVICES/CAREGIVER SUPPORT',
#        'NYCHA COMMUNITY CENTER - CASE MANAGEMENT - SENIORS',
#        'OUTDOOR PARKING - TOW POUND', 'LADDERS FOR LEADERS (LFL)',
#        'CRAFTS',
#        'MEDICALLY SUPERVISED OUTPATIENT-OASAS, VOCATIONAL REHABILITATION-OASAS, METHADONE MAINTENANCE-OASAS',
#        'NON-MEDICAID CARE COORDINATION; (NON-LICENSED PROGRAM)-OMH, NON-MEDICAID CARE COORDINATION (OMH)-OMH',
#        'APPROVED PRIVATE SCHOOLS FOR SWD',
#        'HOME BASED CRISIS INTERVENTION-OMH',
#        'PRIVATELY OWNED PUBLIC SPACE',
#        'SUPPORTED SRO-OMH, CRISIS/RESPITE BEDS-OMH',
#        'CHILD ADVOCACY CENTER', 'CLINIC TREATMENT FACILITY-OPWDD',
#        'NYCHA COMMUNITY CENTER - YOUTH PROGRAMS',
#        'NYCHA COMMUNITY CENTER - CITIBIKE BIKE STORAGE',
#        'NYCHA COMMUNITY CENTER - HEAD START / JOBS PLUS / COMMUNITY CENTER',
#        'NYCHA COMMUNITY CENTER - COMMUNITY CENTER/ HEALTH CLINIC',
#        'REGENTS APPROVED FOREIGN COLLEGES', 'TRAILWAY',
#        'INDOOR STORAGE - BULK MATERIAL',
#        'NYCHA COMMUNITY CENTER - HEALTH CLINIC (MENTAL)',
#        'NYCHA COMMUNITY CENTER - CHILD CARE - EARLY INTERVENTION (ABA)',
#        'NEIGHBORHOOD EMPLOYMENT SERVICES',
#        'NYCHA COMMUNITY CENTER - FAMILY/YOUTH PROGRAM / MEALS ON WHEELS OFFICES',
#        'NY NY III SUPPORTED HOUSING-OASAS, SUPPORTED HOUSING-OMH',
#        'EPILEPSY SERVICES-OPWDD', 'GENERAL GRANT NATIONAL MEMORIAL',
#        'FEDERAL HALL NATIONAL MEMORIAL',
#        'NYCHA COMMUNITY CENTER - OFFICE SPACE, TRAINING, RA USE',
#        'MATERIAL PROCESSING FACILITY', 'HOMEMAKER SERVICES-OPWDD',
#        'ON-SITE REHABILITATION-OMH, SUPPORTED HOUSING-OMH',
#        'COMMUNITY SERVICES-OASAS',
#        'CPEP CRISIS INTERVENTION-OMH, CPEP CRISIS OUTREACH-OMH',
#        'NY CONNECTS',
#        'NYCHA COMMUNITY CENTER - SENIOR CENTER/ NORC / COMMUNITY CENTER',
#        'ASSISTED COMPETITIVE EMPLOYMENT-OMH, ADVOCACY SERVICES-OMH',
#        'NYCHA COMMUNITY CENTER - SCHOOL',
#        'NYCHA COMMUNITY CENTER - FOOD PANTRY',
#        'NYCHA COMMUNITY CENTER - UNKNOWN',
#        'NYCHA COMMUNITY CENTER - STORAGE', 'COVID19 PROGRAMS',
#        'SPECIAL DEMO',
#        'NYCHA COMMUNITY CENTER - CASE MANAGEMENT/ REFERRAL SERVICES',
#        'NYCHA COMMUNITY CENTER - LIBRARY', 'ON-SITE REHABILITATION-OMH',
#        'SUNY - COMMUNITY COLLEGES', 'STATE PARK PRESERVE',
#        'NYCHA COMMUNITY CENTER - MANHATTAN CCTV UNIT',
#        'NYCHA COMMUNITY CENTER - URBAN FAMILY CENTER - SHELTERS',
#        'NYCHA COMMUNITY CENTER - FAMILY SERVICES',
#        'NYCHA COMMUNITY CENTER - SENIOR CENTER / JOB READINESS / ESL',
#        'METRO-NORTH MAINTENANCE AND OTHER FACILITY',
#        'NYCHA COMMUNITY CENTER - VACANT',
#        'INDOOR STORAGE - PRINTED MATERIAL/SUPPLIES',
#        'NYCHA COMMUNITY CENTER - RESERVED - OPERATIONS',
#        'NYCHA COMMUNITY CENTER - NORC/ CHILD CARE / COMMUNITY CENTER / HEALTH CLINIC',
#        'NYCHA COMMUNITY CENTER - COMMUNITY CENTER / SPORTS'], dtype=object)

# %%
facilities_df['facdomain'].unique()
# Out:
# array(['EDUCATION, CHILD WELFARE, AND YOUTH',
#        'PARKS, GARDENS, AND HISTORICAL SITES',
#        'CORE INFRASTRUCTURE AND TRANSPORTATION',
#        'LIBRARIES AND CULTURAL PROGRAMS', 'ADMINISTRATION OF GOVERNMENT',
#        'HEALTH AND HUMAN SERVICES',
#        'PUBLIC SAFETY, EMERGENCY SERVICES, AND ADMINISTRATION OF JUSTICE'],
#       dtype=object)

# %%
facilities_df['facgroup'].unique()
# Out:
# array(['DAY CARE AND PRE-KINDERGARTEN', 'SCHOOLS (K-12)',
#        'HISTORICAL SITES', 'CHILD SERVICES AND WELFARE', 'TRANSPORTATION',
#        'VOCATIONAL AND PROPRIETARY SCHOOLS', 'PARKS AND PLAZAS',
#        'CULTURAL INSTITUTIONS', 'SOLID WASTE',
#        'CITY AGENCY PARKING, MAINTENANCE, AND STORAGE', 'HEALTH CARE',
#        'WATER AND WASTEWATER', 'LIBRARIES',
#        'OFFICES, TRAINING, AND TESTING', 'PUBLIC SAFETY',
#        'JUSTICE AND CORRECTIONS', 'HUMAN SERVICES', 'HIGHER EDUCATION',
#        'ADULT SERVICES', 'EMERGENCY SERVICES',
#        'MATERIAL SUPPLIES AND MARKETS', 'OTHER PROPERTY',
#        'YOUTH SERVICES', 'CAMPS', 'TELECOMMUNICATIONS'], dtype=object)

# %%
facilities_df.crs, print(f"Shape: {facilities_df.shape}")
# Out:
# Shape: (34171, 38)
# (<Geographic 2D CRS: GEOGCS["WGS84(DD)",DATUM["WGS84",SPHEROID["WGS84", ...>
#  Name: WGS84(DD)
#  Axis Info [ellipsoidal]:
#  - lon[east]: Longitude (degree)
#  - lat[north]: Latitude (degree)
#  Area of Use:
#  - undefined
#  Datum: WGS84
#  - Ellipsoid: WGS84
#  - Prime Meridian: Greenwich,
#  None)

# %%
facilities_df.plot(figsize=(10,10))
plt.title("Mapa obiektów")
# Out:
# Text(0.5, 1.0, 'Mapa obiektów')

# %% [markdown]
# # Digital City Map
# https://data.cityofnewyork.us/City-Government/Digital-City-Map-Shapefile/m2vu-mgzw <br>
# https://www.nyc.gov/site/planning/data-maps/open-data/dwn-digital-city-map.page <br>
# https://s-media.nyc.gov/agencies/dcp/assets/files/pdf/data-tools/bytes/dcm.pdf

# %%
city_map_df = gpd.read_file(DATA_PATH+'Digital City Map   Shapefile.zip')

# %%
city_map_df.plot(figsize=(10,10))
plt.title("Mapa miasta")
print(f"Shape: {city_map_df.shape}")
# Out:
# Shape: (5363, 22)

# %% [markdown]
# # Rest, for example subway stations

# %%
city_map_subway_df = gpd.read_file(DATA_PATH+'ny_data/subway_stations')
city_map_subway_df.plot(figsize=(10,10))
plt.title("Mapa stacji metra")
print(f"Shape: {city_map_subway_df.shape}")
# Out:
# Shape: (491, 15)

# %%
city_map_subway_df.head()
# Out:
#    OBJECTID     ID          NAME         ALT_NAME         CROSS_ST  \
# 0       1.0  376.0  Cortlandt St             None        Church St
# 1       2.0    2.0     Rector St             None             None
# 2       3.0    1.0   South Ferry             None             None
# 3       4.0  125.0      138th St  Grand Concourse  Grand Concourse
# 4       5.0  126.0      149th St  Grand Concourse  Grand Concourse
#
#                                 LONG_NAME                             LABEL  \
# 0            Cortlandt St (R,W) Manhattan                Cortlandt St (R,W)
# 1                 Rector St (1) Manhattan                     Rector St (1)
# 2               South Ferry (1) Manhattan                   South Ferry (1)
# 3  138th St / Grand Concourse (4,5) Bronx  138th St / Grand Concourse (4,5)
# 4    149th St / Grand Concourse (4) Bronx    149th St / Grand Concourse (4)
#
#      BOROUGH NGHBHD ROUTES TRANSFERS   COLOR  EXPRESS CLOSED  \
# 0  Manhattan   None    R,W       R,W  YELLOW     None   None
# 1  Manhattan   None      1         1     RED     None   None
# 2  Manhattan   None      1         1     RED     None   None
# 3      Bronx   None    4,5       4,5   GREEN     None   None
# 4      Bronx   None      4     2,4,5   GREEN  express   None
#
#                          geometry
# 0  POINT (583521.854 4507077.863)
# 1  POINT (583324.487 4506805.373)
# 2  POINT (583304.182 4506069.654)
# 3  POINT (590250.106 4518558.020)
# 4  POINT (590454.740 4519145.720)

# %% [markdown]
# # NYPD Complaint Data Current (Year To Date)
# https://data.cityofnewyork.us/Public-Safety/NYPD-Complaint-Data-Current-Year-To-Date-/5uac-w243 <br>

# %%
nyc_comp_df = gpd.read_file(DATA_PATH+'NYPD Complaint Data Current (Year To Date).zip')

# %%
nyc_comp_df
# Out:
#          cmplnt_num  addr_pct_c        boro_nm  date_cmpln    time_cmpln  \
# 0         270652286        43.0          BRONX  2023-07-01  00:00:00.000
# 1       269679657H1         NaN      MANHATTAN  2023-06-09  00:00:00.000
# 2         270825324       122.0  STATEN ISLAND  2023-07-02  00:00:00.000
# 3         274700214         1.0      MANHATTAN  2023-09-19  00:00:00.000
# 4         272352661       123.0  STATEN ISLAND  2023-08-03  00:00:00.000
# ...             ...         ...            ...         ...           ...
# 415305    267120705       103.0         QUEENS  2023-04-23  00:00:00.000
# 415306    264248232       105.0         QUEENS  2023-02-19  00:00:00.000
# 415307    267026380       105.0         QUEENS  2023-04-21  00:00:00.000
# 415308    269438940       107.0         QUEENS  2023-06-06  00:00:00.000
# 415309    275274817       105.0         QUEENS  2023-09-29  00:00:00.000
#
#        cmplnt_fr_  date_cmp_2    time_cmp_2 cmplnt_to_ crm_atpt_c  ...  \
# 0        05:00:00        None          None     (null)  COMPLETED  ...
# 1        08:13:00        None          None     (null)  COMPLETED  ...
# 2        19:30:00  2023-07-02  00:00:00.000   20:00:00  COMPLETED  ...
# 3        18:05:00  2023-09-19  00:00:00.000   20:15:00  COMPLETED  ...
# 4        17:20:00  2023-08-03  00:00:00.000   17:35:00  COMPLETED  ...
# ...           ...         ...           ...        ...        ...  ...
# 415305   03:55:00  2023-04-23  00:00:00.000   04:03:00  COMPLETED  ...
# 415306   09:00:00  2023-02-26  00:00:00.000   08:00:00  COMPLETED  ...
# 415307   01:50:00  2023-04-21  00:00:00.000   01:53:00  COMPLETED  ...
# 415308   09:25:00  2023-06-06  00:00:00.000   09:27:00  COMPLETED  ...
# 415309   22:00:00  2023-09-29  00:00:00.000   22:30:00  COMPLETED  ...
#
#        vic_sex  x_coord_cd  y_coord_cd   latitude  longitude lat_lon_ad  \
# 0            F   1020219.0    239110.0  40.822912 -73.870041       None
# 1            M         NaN         NaN        NaN        NaN       None
# 2            F    946681.0    142778.0  40.558491 -74.135201       None
# 3            M    980863.0    198480.0  40.711458 -74.012216       None
# 4            F    926582.0    136703.0  40.541709 -74.207482       None
# ...        ...         ...         ...        ...        ...        ...
# 415305       M   1044256.0    197271.0  40.707937 -73.783565       None
# 415306       F   1062455.0    212970.0  40.750884 -73.717741       None
# 415307       M   1060576.0    203292.0  40.724337 -73.724633       None
# 415308       F   1048247.0    200458.0  40.716656 -73.769140       None
# 415309       F   1055789.0    184083.0  40.671654 -73.742106       None
#
#        lat_lon_ci lat_lon_st lat_lon_zi                    geometry
# 0            None       None       None  POINT (-73.87004 40.82291)
# 1            None       None       None                        None
# 2            None       None       None  POINT (-74.13520 40.55849)
# 3            None       None       None  POINT (-74.01222 40.71146)
# 4            None       None       None  POINT (-74.20748 40.54171)
# ...           ...        ...        ...                         ...
# 415305       None       None       None  POINT (-73.78356 40.70794)
# 415306       None       None       None  POINT (-73.71774 40.75088)
# 415307       None       None       None  POINT (-73.72463 40.72434)
# 415308       None       None       None  POINT (-73.76914 40.71666)
# 415309       None       None       None  POINT (-73.74211 40.67165)
#
# [415310 rows x 42 columns]

# %%
nyc_comp_df[(nyc_comp_df['latitude'] == 0) | (nyc_comp_df['longitude'] == 0)]
# Out:
#        cmplnt_num  addr_pct_c    boro_nm  date_cmpln    time_cmpln cmplnt_fr_  \
# 346097  265828516         1.0  MANHATTAN  2023-03-29  00:00:00.000   01:55:00
#
#         date_cmp_2    time_cmp_2 cmplnt_to_ crm_atpt_c  ... vic_sex  \
# 346097  2023-03-29  00:00:00.000   02:21:00  COMPLETED  ...       E
#
#         x_coord_cd  y_coord_cd latitude  longitude lat_lon_ad lat_lon_ci  \
# 346097         0.0         0.0      0.0        0.0       None       None
#
#        lat_lon_st lat_lon_zi                 geometry
# 346097       None       None  POINT (0.00000 0.00000)
#
# [1 rows x 42 columns]

# %%
nyc_comp_df.replace(0, pd.NA, inplace=True)
nyc_comp_df_cleaned = nyc_comp_df.dropna(subset=['longitude', 'latitude'])
nyc_comp_df_cleaned[(nyc_comp_df_cleaned['latitude'] == 0) | (nyc_comp_df_cleaned['longitude'] == 0)]
# Out:
# Empty GeoDataFrame
# Columns: [cmplnt_num, addr_pct_c, boro_nm, date_cmpln, time_cmpln, cmplnt_fr_, date_cmp_2, time_cmp_2, cmplnt_to_, crm_atpt_c, hadevelopt, housing_ps, jurisdicti, juris_desc, ky_cd, law_cat_cd, loc_of_occ, ofns_desc, parks_nm, patrol_bor, pd_cd, pd_desc, prem_typ_d, date_rpt_d, time_rpt_d, station_na, susp_age_g, susp_race, susp_sex, transit_di, vic_age_gr, vic_race, vic_sex, x_coord_cd, y_coord_cd, latitude, longitude, lat_lon_ad, lat_lon_ci, lat_lon_st, lat_lon_zi, geometry]
# Index: []
#
# [0 rows x 42 columns]

# %%
nyc_comp_df_cleaned.plot(figsize=(10,10))
plt.title("Mapa przestępstw")
# Out:
# Text(0.5, 1.0, 'Mapa przestępstw')
